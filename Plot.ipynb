# %%
# Exploratory data visualization

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 6]

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'])

# %%
# Method 1: on the same Axis
sns.distplot( tips["sepal_length"] , color="skyblue", label="Sepal Length")
sns.distplot( df["sepal_width"] , color="red", label="Sepal Width")
sns.plt.legend()

# %%
sns.catplot(x="sex", y="total_bill", kind="box", data=tips);

# %%
tips['treatment'] = np.where(tips['sex']=='Male', 1, 2)

# %%
sns.catplot(x="treatment", y="total_bill", kind="box", data=tips);

# %%
# "point", "bar", "strip", "swarm", "box", "violin", or "boxen"
# sns.catplot(x='treatment', y = 'total_bill', kind='swarm', data=tips)
# sns.catplot(x='treatment', y = 'total_bill', kind='boxen', data=tips)
sns.catplot(x='treatment', y = 'total_bill', kind='violin', data=tips)
